# %% [markdown]
# # Settings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install wandb
# !wandb login
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 8.1 MB/s
# ...
#      |████████████████████████████████| 97 kB 8.3 MB/s
# ...
#      |████████████████████████████████| 180 kB 68.2 MB/s
# ...
#      |████████████████████████████████| 140 kB 68.6 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.2 MB/s
# ...
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=34c1c9498ca76fce393b2dcce21399c85a2be17f28dc49f37ea652d1bff08722
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8807 sha256=064cbae9978a49098ee79d90024638efca5dc38d477799351de4911fb6ef5f44
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built subprocess32 pathtools
# ...
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# ...

# %%
# !pip install efficientunet-pytorch
# Out:
# ...
#   Created wheel for efficientunet-pytorch: filename=efficientunet_pytorch-0.0.6-py3-none-any.whl size=9459 sha256=8c81c7bf68fdc5d79357b957b33cc588fa97ed06fe335aeb78259807fd132054
#   Stored in directory: /root/.cache/pip/wheels/84/c5/98/c9bb8ce1c9427466455cbbc3a8117485ca7eab38a03558457c
# Successfully built efficientunet-pytorch
# ...

# %% [markdown]
# # UNet

# %% [markdown]
# ## Train

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/dent' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/UNet/dent' \
--train_continue 'off'
# Out:
# Streaming output truncated to the last 5000 lines.
# Train: EPOCH 0040 / 0050 | BATCH 0252 \ 0423 | LOSS 0.0460
# Train: EPOCH 0040 / 0050 | BATCH 0253 \ 0423 | LOSS 0.0459
# Train: EPOCH 0040 / 0050 | BATCH 0254 \ 0423 | LOSS 0.0458
# Train: EPOCH 0040 / 0050 | BATCH 0255 \ 0423 | LOSS 0.0457
# Train: EPOCH 0040 / 0050 | BATCH 0256 \ 0423 | LOSS 0.0463
# Train: EPOCH 0040 / 0050 | BATCH 0257 \ 0423 | LOSS 0.0466
# Train: EPOCH 0040 / 0050 | BATCH 0258 \ 0423 | LOSS 0.0467
# Train: EPOCH 0040 / 0050 | BATCH 0259 \ 0423 | LOSS 0.0467
# Train: EPOCH 0040 / 0050 | BATCH 0260 \ 0423 | LOSS 0.0466
# Train: EPOCH 0040 / 0050 | BATCH 0261 \ 0423 | LOSS 0.0465
# Train: EPOCH 0040 / 0050 | BATCH 0262 \ 0423 | LOSS 0.0464
# Train: EPOCH 0040 / 0050 | BATCH 0263 \ 0423 | LOSS 0.0463
# Train: EPOCH 0040 / 0050 | BATCH 0264 \ 0423 | LOSS 0.0462
# Train: EPOCH 0040 / 0050 | BATCH 0265 \ 0423 | LOSS 0.0461
# Train: EPOCH 0040 / 0050 | BATCH 0266 \ 0423 | LOSS 0.0464
# ...

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/scratch' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/UNet/scratch' \
--train_continue 'off'
# Out:
# Streaming output truncated to the last 5000 lines.
# Train: EPOCH 0040 / 0050 | BATCH 0252 \ 0423 | LOSS 0.0766
# Train: EPOCH 0040 / 0050 | BATCH 0253 \ 0423 | LOSS 0.0765
# Train: EPOCH 0040 / 0050 | BATCH 0254 \ 0423 | LOSS 0.0764
# Train: EPOCH 0040 / 0050 | BATCH 0255 \ 0423 | LOSS 0.0764
# Train: EPOCH 0040 / 0050 | BATCH 0256 \ 0423 | LOSS 0.0766
# Train: EPOCH 0040 / 0050 | BATCH 0257 \ 0423 | LOSS 0.0765
# Train: EPOCH 0040 / 0050 | BATCH 0258 \ 0423 | LOSS 0.0765
# Train: EPOCH 0040 / 0050 | BATCH 0259 \ 0423 | LOSS 0.0763
# Train: EPOCH 0040 / 0050 | BATCH 0260 \ 0423 | LOSS 0.0764
# Train: EPOCH 0040 / 0050 | BATCH 0261 \ 0423 | LOSS 0.0766
# Train: EPOCH 0040 / 0050 | BATCH 0262 \ 0423 | LOSS 0.0766
# Train: EPOCH 0040 / 0050 | BATCH 0263 \ 0423 | LOSS 0.0766
# Train: EPOCH 0040 / 0050 | BATCH 0264 \ 0423 | LOSS 0.0765
# Train: EPOCH 0040 / 0050 | BATCH 0265 \ 0423 | LOSS 0.0765
# Train: EPOCH 0040 / 0050 | BATCH 0266 \ 0423 | LOSS 0.0764
# ...

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/spacing' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/UNet/spacing' \
--train_continue 'off'
# Out:
# Streaming output truncated to the last 5000 lines.
# Train: EPOCH 0032 / 0050 | BATCH 0257 \ 0308 | LOSS 0.0125
# Train: EPOCH 0032 / 0050 | BATCH 0258 \ 0308 | LOSS 0.0125
# Train: EPOCH 0032 / 0050 | BATCH 0259 \ 0308 | LOSS 0.0125
# Train: EPOCH 0032 / 0050 | BATCH 0260 \ 0308 | LOSS 0.0125
# Train: EPOCH 0032 / 0050 | BATCH 0261 \ 0308 | LOSS 0.0125
# Train: EPOCH 0032 / 0050 | BATCH 0262 \ 0308 | LOSS 0.0125
# Train: EPOCH 0032 / 0050 | BATCH 0263 \ 0308 | LOSS 0.0124
# Train: EPOCH 0032 / 0050 | BATCH 0264 \ 0308 | LOSS 0.0124
# Train: EPOCH 0032 / 0050 | BATCH 0265 \ 0308 | LOSS 0.0124
# Train: EPOCH 0032 / 0050 | BATCH 0266 \ 0308 | LOSS 0.0125
# Train: EPOCH 0032 / 0050 | BATCH 0267 \ 0308 | LOSS 0.0125
# Train: EPOCH 0032 / 0050 | BATCH 0268 \ 0308 | LOSS 0.0125
# Train: EPOCH 0032 / 0050 | BATCH 0269 \ 0308 | LOSS 0.0124
# Train: EPOCH 0032 / 0050 | BATCH 0270 \ 0308 | LOSS 0.0124
# Train: EPOCH 0032 / 0050 | BATCH 0271 \ 0308 | LOSS 0.0124
# ...

# %% [markdown]
# ## Test

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/dent' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/UNet/dent' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/UNet/dent' \
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# TEST: BATCH 0001 \ 0053 | IoU 1.0000
# TEST: BATCH 0002 \ 0053 | IoU 1.0000
# TEST: BATCH 0003 \ 0053 | IoU 0.0000
# TEST: BATCH 0004 \ 0053 | IoU 0.0000
# TEST: BATCH 0005 \ 0053 | IoU 0.0000
# TEST: BATCH 0006 \ 0053 | IoU 0.0000
# TEST: BATCH 0007 \ 0053 | IoU 0.0000
# TEST: BATCH 0008 \ 0053 | IoU 0.0000
# TEST: BATCH 0009 \ 0053 | IoU 0.0000
# TEST: BATCH 0010 \ 0053 | IoU 0.0000
# TEST: BATCH 0011 \ 0053 | IoU 0.0000
# TEST: BATCH 0012 \ 0053 | IoU 0.0000
# TEST: BATCH 0013 \ 0053 | IoU 1.0000
# ...

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/scratch' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/UNet/scratch' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/UNet/scratch' \
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py", line 76, in <module>
#     net, optim, st_epoch = load(ckpt_dir=ckpt_dir, net=net, optim=optim)
#   File "/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/util.py", line 26, in load
#     net.load_state_dict(dict_model['net'])
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1483, in load_state_dict
#     self.__class__.__name__, "\n\t".join(error_msgs)))
# ...

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/spacing' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/UNet/spacing' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/UNet/spacing' \

# %% [markdown]
# #b0

# %% [markdown]
# ## Train

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/dent' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b0/dent' \
--train_continue 'off'
# Out:
# Streaming output truncated to the last 5000 lines.
# Train: EPOCH 0040 / 0050 | BATCH 0252 \ 0423 | LOSS 0.0268
# Train: EPOCH 0040 / 0050 | BATCH 0253 \ 0423 | LOSS 0.0269
# Train: EPOCH 0040 / 0050 | BATCH 0254 \ 0423 | LOSS 0.0268
# Train: EPOCH 0040 / 0050 | BATCH 0255 \ 0423 | LOSS 0.0267
# Train: EPOCH 0040 / 0050 | BATCH 0256 \ 0423 | LOSS 0.0266
# Train: EPOCH 0040 / 0050 | BATCH 0257 \ 0423 | LOSS 0.0267
# Train: EPOCH 0040 / 0050 | BATCH 0258 \ 0423 | LOSS 0.0269
# Train: EPOCH 0040 / 0050 | BATCH 0259 \ 0423 | LOSS 0.0269
# Train: EPOCH 0040 / 0050 | BATCH 0260 \ 0423 | LOSS 0.0269
# Train: EPOCH 0040 / 0050 | BATCH 0261 \ 0423 | LOSS 0.0268
# Train: EPOCH 0040 / 0050 | BATCH 0262 \ 0423 | LOSS 0.0268
# Train: EPOCH 0040 / 0050 | BATCH 0263 \ 0423 | LOSS 0.0267
# Train: EPOCH 0040 / 0050 | BATCH 0264 \ 0423 | LOSS 0.0268
# Train: EPOCH 0040 / 0050 | BATCH 0265 \ 0423 | LOSS 0.0268
# Train: EPOCH 0040 / 0050 | BATCH 0266 \ 0423 | LOSS 0.0268
# ...

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/scratch' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b0/scratch' \
--train_continue 'off'
# Out:
# Streaming output truncated to the last 5000 lines.
# Train: EPOCH 0040 / 0050 | BATCH 0252 \ 0423 | LOSS 0.0407
# Train: EPOCH 0040 / 0050 | BATCH 0253 \ 0423 | LOSS 0.0407
# Train: EPOCH 0040 / 0050 | BATCH 0254 \ 0423 | LOSS 0.0407
# Train: EPOCH 0040 / 0050 | BATCH 0255 \ 0423 | LOSS 0.0409
# Train: EPOCH 0040 / 0050 | BATCH 0256 \ 0423 | LOSS 0.0410
# Train: EPOCH 0040 / 0050 | BATCH 0257 \ 0423 | LOSS 0.0410
# Train: EPOCH 0040 / 0050 | BATCH 0258 \ 0423 | LOSS 0.0411
# Train: EPOCH 0040 / 0050 | BATCH 0259 \ 0423 | LOSS 0.0411
# Train: EPOCH 0040 / 0050 | BATCH 0260 \ 0423 | LOSS 0.0411
# Train: EPOCH 0040 / 0050 | BATCH 0261 \ 0423 | LOSS 0.0411
# Train: EPOCH 0040 / 0050 | BATCH 0262 \ 0423 | LOSS 0.0411
# Train: EPOCH 0040 / 0050 | BATCH 0263 \ 0423 | LOSS 0.0411
# Train: EPOCH 0040 / 0050 | BATCH 0264 \ 0423 | LOSS 0.0411
# Train: EPOCH 0040 / 0050 | BATCH 0265 \ 0423 | LOSS 0.0410
# Train: EPOCH 0040 / 0050 | BATCH 0266 \ 0423 | LOSS 0.0409
# ...

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/spacing' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b0/spacing' \
--train_continue 'off'
# Out:
# Streaming output truncated to the last 5000 lines.
# Train: EPOCH 0036 / 0050 | BATCH 0221 \ 0308 | LOSS 0.0066
# Train: EPOCH 0036 / 0050 | BATCH 0222 \ 0308 | LOSS 0.0066
# Train: EPOCH 0036 / 0050 | BATCH 0223 \ 0308 | LOSS 0.0066
# Train: EPOCH 0036 / 0050 | BATCH 0224 \ 0308 | LOSS 0.0066
# Train: EPOCH 0036 / 0050 | BATCH 0225 \ 0308 | LOSS 0.0066
# Train: EPOCH 0036 / 0050 | BATCH 0226 \ 0308 | LOSS 0.0066
# Train: EPOCH 0036 / 0050 | BATCH 0227 \ 0308 | LOSS 0.0066
# Train: EPOCH 0036 / 0050 | BATCH 0228 \ 0308 | LOSS 0.0066
# Train: EPOCH 0036 / 0050 | BATCH 0229 \ 0308 | LOSS 0.0066
# Train: EPOCH 0036 / 0050 | BATCH 0230 \ 0308 | LOSS 0.0066
# Train: EPOCH 0036 / 0050 | BATCH 0231 \ 0308 | LOSS 0.0066
# Train: EPOCH 0036 / 0050 | BATCH 0232 \ 0308 | LOSS 0.0066
# Train: EPOCH 0036 / 0050 | BATCH 0233 \ 0308 | LOSS 0.0066
# Train: EPOCH 0036 / 0050 | BATCH 0234 \ 0308 | LOSS 0.0066
# Train: EPOCH 0036 / 0050 | BATCH 0235 \ 0308 | LOSS 0.0066
# ...

# %% [markdown]
# ## Test

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/dent' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint3/dent' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results3/dent' \
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# TEST: BATCH 0001 \ 0053 | IoU 1.0000
# TEST: BATCH 0002 \ 0053 | IoU 1.0000
# TEST: BATCH 0003 \ 0053 | IoU 0.0000
# TEST: BATCH 0004 \ 0053 | IoU 0.0386
# TEST: BATCH 0005 \ 0053 | IoU 0.0000
# TEST: BATCH 0006 \ 0053 | IoU 0.2627
# TEST: BATCH 0007 \ 0053 | IoU 0.0000
# TEST: BATCH 0008 \ 0053 | IoU 0.0310
# TEST: BATCH 0009 \ 0053 | IoU 0.0000
# TEST: BATCH 0010 \ 0053 | IoU 0.0000
# TEST: BATCH 0011 \ 0053 | IoU 0.3805
# TEST: BATCH 0012 \ 0053 | IoU 0.0000
# TEST: BATCH 0013 \ 0053 | IoU 1.0000
# ...

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy/scratch' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/scratch' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/scratch' \
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# TEST: BATCH 0001 \ 0053 | IoU 0.0000
# TEST: BATCH 0002 \ 0053 | IoU 0.0000
# TEST: BATCH 0003 \ 0053 | IoU 0.5270
# TEST: BATCH 0004 \ 0053 | IoU 0.8195
# TEST: BATCH 0005 \ 0053 | IoU 0.4199
# TEST: BATCH 0006 \ 0053 | IoU 0.5044
# TEST: BATCH 0007 \ 0053 | IoU 0.7044
# TEST: BATCH 0008 \ 0053 | IoU 0.4540
# TEST: BATCH 0009 \ 0053 | IoU 0.8048
# TEST: BATCH 0010 \ 0053 | IoU 0.4660
# TEST: BATCH 0011 \ 0053 | IoU 0.6338
# TEST: BATCH 0012 \ 0053 | IoU 0.4676
# TEST: BATCH 0013 \ 0053 | IoU 0.3931
# ...

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/spacing' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint3/spacing' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results3/spacing' \
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# TEST: BATCH 0001 \ 0039 | IoU 0.0000
# TEST: BATCH 0002 \ 0039 | IoU 0.0113
# TEST: BATCH 0003 \ 0039 | IoU 0.0000
# TEST: BATCH 0004 \ 0039 | IoU 0.0000
# TEST: BATCH 0005 \ 0039 | IoU 1.0000
# TEST: BATCH 0006 \ 0039 | IoU 0.0548
# TEST: BATCH 0007 \ 0039 | IoU 0.0363
# TEST: BATCH 0008 \ 0039 | IoU 0.3724
# TEST: BATCH 0009 \ 0039 | IoU 0.0000
# TEST: BATCH 0010 \ 0039 | IoU 0.0000
# TEST: BATCH 0011 \ 0039 | IoU 0.2541
# TEST: BATCH 0012 \ 0039 | IoU 0.0386
# TEST: BATCH 0013 \ 0039 | IoU 0.0000
# ...

# %% [markdown]
# # b1

# %% [markdown]
# ## Train

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/dent' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b1/dent' \
--train_continue 'off'
# Out:
# Streaming output truncated to the last 5000 lines.
# Train: EPOCH 0040 / 0050 | BATCH 0252 \ 0423 | LOSS 0.0311
# Train: EPOCH 0040 / 0050 | BATCH 0253 \ 0423 | LOSS 0.0310
# Train: EPOCH 0040 / 0050 | BATCH 0254 \ 0423 | LOSS 0.0310
# Train: EPOCH 0040 / 0050 | BATCH 0255 \ 0423 | LOSS 0.0317
# Train: EPOCH 0040 / 0050 | BATCH 0256 \ 0423 | LOSS 0.0321
# Train: EPOCH 0040 / 0050 | BATCH 0257 \ 0423 | LOSS 0.0321
# Train: EPOCH 0040 / 0050 | BATCH 0258 \ 0423 | LOSS 0.0323
# Train: EPOCH 0040 / 0050 | BATCH 0259 \ 0423 | LOSS 0.0326
# Train: EPOCH 0040 / 0050 | BATCH 0260 \ 0423 | LOSS 0.0324
# Train: EPOCH 0040 / 0050 | BATCH 0261 \ 0423 | LOSS 0.0324
# Train: EPOCH 0040 / 0050 | BATCH 0262 \ 0423 | LOSS 0.0323
# Train: EPOCH 0040 / 0050 | BATCH 0263 \ 0423 | LOSS 0.0325
# Train: EPOCH 0040 / 0050 | BATCH 0264 \ 0423 | LOSS 0.0324
# Train: EPOCH 0040 / 0050 | BATCH 0265 \ 0423 | LOSS 0.0323
# Train: EPOCH 0040 / 0050 | BATCH 0266 \ 0423 | LOSS 0.0324
# ...

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/scratch' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b1/scratch' \
--train_continue 'off'
# Out:
# Streaming output truncated to the last 5000 lines.
# Train: EPOCH 0040 / 0050 | BATCH 0252 \ 0423 | LOSS 0.0422
# Train: EPOCH 0040 / 0050 | BATCH 0253 \ 0423 | LOSS 0.0422
# Train: EPOCH 0040 / 0050 | BATCH 0254 \ 0423 | LOSS 0.0421
# Train: EPOCH 0040 / 0050 | BATCH 0255 \ 0423 | LOSS 0.0421
# Train: EPOCH 0040 / 0050 | BATCH 0256 \ 0423 | LOSS 0.0421
# Train: EPOCH 0040 / 0050 | BATCH 0257 \ 0423 | LOSS 0.0422
# Train: EPOCH 0040 / 0050 | BATCH 0258 \ 0423 | LOSS 0.0421
# Train: EPOCH 0040 / 0050 | BATCH 0259 \ 0423 | LOSS 0.0422
# Train: EPOCH 0040 / 0050 | BATCH 0260 \ 0423 | LOSS 0.0422
# Train: EPOCH 0040 / 0050 | BATCH 0261 \ 0423 | LOSS 0.0423
# Train: EPOCH 0040 / 0050 | BATCH 0262 \ 0423 | LOSS 0.0422
# Train: EPOCH 0040 / 0050 | BATCH 0263 \ 0423 | LOSS 0.0423
# Train: EPOCH 0040 / 0050 | BATCH 0264 \ 0423 | LOSS 0.0422
# Train: EPOCH 0040 / 0050 | BATCH 0265 \ 0423 | LOSS 0.0423
# Train: EPOCH 0040 / 0050 | BATCH 0266 \ 0423 | LOSS 0.0423
# ...

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/spacing' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b1/spacing' \
--train_continue 'off'
# Out:
# Streaming output truncated to the last 5000 lines.
# Train: EPOCH 0036 / 0050 | BATCH 0221 \ 0308 | LOSS 0.0072
# Train: EPOCH 0036 / 0050 | BATCH 0222 \ 0308 | LOSS 0.0072
# Train: EPOCH 0036 / 0050 | BATCH 0223 \ 0308 | LOSS 0.0072
# Train: EPOCH 0036 / 0050 | BATCH 0224 \ 0308 | LOSS 0.0072
# Train: EPOCH 0036 / 0050 | BATCH 0225 \ 0308 | LOSS 0.0072
# Train: EPOCH 0036 / 0050 | BATCH 0226 \ 0308 | LOSS 0.0072
# Train: EPOCH 0036 / 0050 | BATCH 0227 \ 0308 | LOSS 0.0072
# Train: EPOCH 0036 / 0050 | BATCH 0228 \ 0308 | LOSS 0.0072
# Train: EPOCH 0036 / 0050 | BATCH 0229 \ 0308 | LOSS 0.0072
# Train: EPOCH 0036 / 0050 | BATCH 0230 \ 0308 | LOSS 0.0072
# Train: EPOCH 0036 / 0050 | BATCH 0231 \ 0308 | LOSS 0.0072
# Train: EPOCH 0036 / 0050 | BATCH 0232 \ 0308 | LOSS 0.0072
# Train: EPOCH 0036 / 0050 | BATCH 0233 \ 0308 | LOSS 0.0072
# Train: EPOCH 0036 / 0050 | BATCH 0234 \ 0308 | LOSS 0.0072
# Train: EPOCH 0036 / 0050 | BATCH 0235 \ 0308 | LOSS 0.0072
# ...

# %% [markdown]
# ## Test

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/dent' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b1/dent' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/b1/dent' \

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/scratch' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b1/scratch' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/b1/scratch' \

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_CarDamage/datasets_gray_npy_final/spacing' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b1/spacing' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/b1/spacing' \

# %% [markdown]
# #b2

# %% [markdown]
# ## Train

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/dent' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b2/dent' \
--train_continue 'off'
# Out:
# Streaming output truncated to the last 5000 lines.
# Train: EPOCH 0040 / 0050 | BATCH 0252 \ 0423 | LOSS 0.0267
# Train: EPOCH 0040 / 0050 | BATCH 0253 \ 0423 | LOSS 0.0268
# Train: EPOCH 0040 / 0050 | BATCH 0254 \ 0423 | LOSS 0.0267
# Train: EPOCH 0040 / 0050 | BATCH 0255 \ 0423 | LOSS 0.0266
# Train: EPOCH 0040 / 0050 | BATCH 0256 \ 0423 | LOSS 0.0265
# Train: EPOCH 0040 / 0050 | BATCH 0257 \ 0423 | LOSS 0.0264
# Train: EPOCH 0040 / 0050 | BATCH 0258 \ 0423 | LOSS 0.0264
# Train: EPOCH 0040 / 0050 | BATCH 0259 \ 0423 | LOSS 0.0263
# Train: EPOCH 0040 / 0050 | BATCH 0260 \ 0423 | LOSS 0.0262
# Train: EPOCH 0040 / 0050 | BATCH 0261 \ 0423 | LOSS 0.0265
# Train: EPOCH 0040 / 0050 | BATCH 0262 \ 0423 | LOSS 0.0265
# Train: EPOCH 0040 / 0050 | BATCH 0263 \ 0423 | LOSS 0.0265
# Train: EPOCH 0040 / 0050 | BATCH 0264 \ 0423 | LOSS 0.0264
# Train: EPOCH 0040 / 0050 | BATCH 0265 \ 0423 | LOSS 0.0264
# Train: EPOCH 0040 / 0050 | BATCH 0266 \ 0423 | LOSS 0.0263
# ...

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/scratch' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b2/scratch' \
--train_continue 'off'
# Out:
# Streaming output truncated to the last 5000 lines.
# Train: EPOCH 0007 / 0050 | BATCH 0117 \ 0423 | LOSS 0.0749
# Train: EPOCH 0007 / 0050 | BATCH 0118 \ 0423 | LOSS 0.0750
# Train: EPOCH 0007 / 0050 | BATCH 0119 \ 0423 | LOSS 0.0748
# Train: EPOCH 0007 / 0050 | BATCH 0120 \ 0423 | LOSS 0.0746
# Train: EPOCH 0007 / 0050 | BATCH 0121 \ 0423 | LOSS 0.0747
# Train: EPOCH 0007 / 0050 | BATCH 0122 \ 0423 | LOSS 0.0746
# Train: EPOCH 0007 / 0050 | BATCH 0123 \ 0423 | LOSS 0.0751
# Train: EPOCH 0007 / 0050 | BATCH 0124 \ 0423 | LOSS 0.0751
# Train: EPOCH 0007 / 0050 | BATCH 0125 \ 0423 | LOSS 0.0749
# Train: EPOCH 0007 / 0050 | BATCH 0126 \ 0423 | LOSS 0.0750
# Train: EPOCH 0007 / 0050 | BATCH 0127 \ 0423 | LOSS 0.0747
# Train: EPOCH 0007 / 0050 | BATCH 0128 \ 0423 | LOSS 0.0750
# Train: EPOCH 0007 / 0050 | BATCH 0129 \ 0423 | LOSS 0.0749
# Train: EPOCH 0007 / 0050 | BATCH 0130 \ 0423 | LOSS 0.0748
# Train: EPOCH 0007 / 0050 | BATCH 0131 \ 0423 | LOSS 0.0749
# ...

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/spacing' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b2/spacing' \
--train_continue 'off'
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py", line 2, in <module>
#   File "/usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py", line 32, in <module>
#     import matplotlib.colorbar
#   File "/usr/local/lib/python3.7/dist-packages/matplotlib/colorbar.py", line 31, in <module>
#     import matplotlib.contour as contour
#   File "/usr/local/lib/python3.7/dist-packages/matplotlib/contour.py", line 17, in <module>
#     import matplotlib.text as text
#   File "/usr/local/lib/python3.7/dist-packages/matplotlib/text.py", line 16, in <module>
#     from .patches import FancyArrowPatch, FancyBboxPatch, Rectangle
#   File "/usr/local/lib/python3.7/dist-packages/matplotlib/patches.py", line 618, in <module>
#     patchdoc = artist.kwdoc(Patch)
#   File "/usr/local/lib/python3.7/dist-packages/matplotlib/artist.py", line 1627, in kwdoc
#     ai = ArtistInspector(artist)
# ...

# %% [markdown]
# ## Test

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/dent' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b2/dent' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/b2/dent' \

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/scratch' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b2/scratch' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/b2/scratch' \

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/spacing' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b2/spacing' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/b2/spacing' \

# %% [markdown]
# #b3

# %% [markdown]
# ## Train

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/dent' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b3/dent' \
--train_continue 'off'
# Out:
# wandb: Currently logged in as: kim1lee3 (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.12.7
# wandb: Syncing run eager-snowball-173
# wandb: ⭐️ View project at https://wandb.ai/kim1lee3/U-Net
# wandb: 🚀 View run at https://wandb.ai/kim1lee3/U-Net/runs/tgbabcnm
# wandb: Run data is saved locally in /content/wandb/run-20211213_085727-tgbabcnm
# wandb: Run `wandb offline` to turn off syncing.
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Train: EPOCH 0001 / 0050 | BATCH 0001 \ 0423 | LOSS 0.6102
# ...

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/scratch' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b3/scratch' \
--train_continue 'off'
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py", line 3, in <module>
#   File "/usr/local/lib/python3.7/dist-packages/torch/__init__.py", line 721, in <module>
#     import torch.utils.data
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/__init__.py", line 38, in <module>
#     from torch.utils.data.dataloader_experimental import DataLoader2
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader_experimental.py", line 11, in <module>
#     from torch.utils.data.datapipes.iter import IterableWrapper
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/datapipes/__init__.py", line 1, in <module>
#     from . import iter
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/datapipes/iter/__init__.py", line 37, in <module>
#     from torch.utils.data.datapipes.iter.selecting import (
# ...

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/spacing' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b3/spacing' \
--train_continue 'off'
# Out:
# wandb: Currently logged in as: kim1lee3 (use `wandb login --relogin` to force relogin)
# Problem at: /content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py 9 <module>
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py", line 9, in <module>
#     wandb.init(project="U-Net", entity="kim1lee3")
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_init.py", line 939, in init
#     raise e
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_init.py", line 917, in init
#     run = wi.init()
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_init.py", line 597, in init
#     _ = backend.interface.communicate_run_start(run_obj)
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface.py", line 216, in communicate_run_start
#     result = self._communicate_run_start(run_start)
# ...

# %% [markdown]
# ## Test

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/dent' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b3/dent' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/b3/dent' \

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/scratch' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b3/scratch' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/b3/scratch' \

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/spacing' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b3/spacing' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/b3/spacing' \

# %% [markdown]
# # b4

# %% [markdown]
# ## Train

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/dent' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b4/dent' \
--train_continue 'off'
# Out:
# python3: can't open file '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py': [Errno 2] No such file or directory

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/scratch' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b4/scratch' \
--train_continue 'off'
# Out:
# python3: can't open file '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py': [Errno 2] No such file or directory

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py' \
--lr 1e-3 --batch_size 4 --num_epoch 50 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/spacing' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b4/spacing' \
--train_continue 'off'
# Out:
# python3: can't open file '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/train2.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Test

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/dent' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b4/dent' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/b4/dent' \

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/scratch' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b4/scratch' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/b4/scratch' \

# %%
# !python3 '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/test2.py' \
--lr 1e-3 --batch_size 4 \
--data_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/datasets_gray_npy_final/spacing' \
--ckpt_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/checkpoint/b4/spacing' \
--result_dir '/content/drive/MyDrive/Colab/Detecting_and_Classifying_Car_Damage/results/b4/spacing' \
